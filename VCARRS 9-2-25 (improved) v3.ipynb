# %%
import astropy
import dogpile.cache
import fuzzywuzzy
import os
import re
import marvin
import marvin.utils.plot.map as mapplot
import matplotlib
import numpy as np
import numpyencoder
import packaging
import pandas
import photutils
import raven
import scipy
import sdss_access
import sdsstools
import webargs
import werkzeug
import yamlordereddictloader
import time
import matplotlib.pyplot as plt
import csv



from marvin import config
from marvin.tools import Maps
from marvin.tools.image import Image
from marvin.tools.cube import Cube
from marvin.tools.query import Query
from marvin.utils.datamodel.query.base import query_params
from marvin.tools import RSS
from marvin.utils.general.general import get_drpall_table
from marvin.api.api import Interaction

from astropy.io import fits
from astropy import units as u
from astropy import constants as C

# %matplotlib inline
plt.style.use('seaborn-darkgrid')  # set matplotlib style sheet

config.mode = 'remote'
config.access = 'public'
config.use_sentry = True
config.setRelease('DR17')
config.setDR('DR17')
#config.sasurl
#config.urlmap
config.switchSasUrl(sasmode='mirror', ngrokid=None, port=5000, test=False, base=None, public=True)
# Out:
# [WARNING]: cannot initiate Sentry error reporting: unknown error. (UserWarning)
# [INFO]: No release version set. Setting default to DR17

# %%
#troubleshooting code

'''
print(os.environ['SAS_BASE_DIR'])
print(marvin.config.urlmap)
testcube = Cube(plateifu='8485-1901')
print(testcube)
print(f"RA: {testcube.ra}")
print(f"Dec: {testcube.dec}")

print(testcube.nsa)

# access the spaxel from the lower left corner of the Cube for 8485-1901
spaxel = testcube.getSpaxel(0,0)
# represent the spaxel
print(spaxel)

flux = spaxel.flux
flux.plot()
print(flux.value, flux.ivar, flux.wavelength)

maps = testcube.getMaps()
print(maps)
ha = maps.getMap('emline_gflux_ha_6564')

#maps.datamodel

print(f"Database access: {config.db}")
'''
# Out:
# '\nprint(os.environ[\'SAS_BASE_DIR\'])\nprint(marvin.config.urlmap)\ntestcube = Cube(plateifu=\'8485-1901\')\nprint(testcube)\nprint(f"RA: {testcube.ra}")\nprint(f"Dec: {testcube.dec}")\n\nprint(testcube.nsa)\n\n# access the spaxel from the lower left corner of the Cube for 8485-1901\nspaxel = testcube.getSpaxel(0,0)\n# represent the spaxel\nprint(spaxel)\n\nflux = spaxel.flux\nflux.plot()\nprint(flux.value, flux.ivar, flux.wavelength)\n\nmaps = testcube.getMaps()\nprint(maps)\nha = maps.getMap(\'emline_gflux_ha_6564\')\n\n#maps.datamodel\n\nprint(f"Database access: {config.db}")\n'

# %%
# get and format an API url to retrieve basic Cube properties
plateifu = '7443-12701'
url = config.urlmap['api']['getCube']['url']

# create and send the request, and retrieve a response
response = Interaction(url.format(name=plateifu))

# check your response's status code
print(response.status_code, "good if 200")
200

# get the data in your response
data = response.getData()
#print(data)
# Out:
# 200 good if 200

# %%
images = Image.from_list(['10839-12701', '8330-3701', '9028-12704', '9033-9102'])
for image in images:
    image.show()
# Out:
# [WARNING]: subprocess 2868 is still running (ResourceWarning)
# [WARNING]: subprocess 12412 is still running (ResourceWarning)
# [WARNING]: subprocess 6712 is still running (ResourceWarning)
# [WARNING]: subprocess 11852 is still running (ResourceWarning)

# %%
#images2 = marvin.utils.general.images.get_images_by_plate(8485)
#for image in images2:
#    image.show()

# %% [markdown]
# **Goal:** redo VCARRS with expanded search using the small angle approx
# * use sklearn to train a model on sorting spiral vs elliptical
# * repeat rotation curve and CLD measurements to calculate DM content
# * create histograms of DM fraction vs # of galaxies, see if there's any differences between spiral and elliptical
# * **hypothesis:** elliptical galaxies have higher DM content due to slower rotation and random stellar orbits

# %%
# testing different ways to get NSA parameters, specifically redshift z

images3 = marvin.utils.general.images.get_random_images(10)
test = []

for item in images3:
    #print(item.__dict__)
    ifu = item.plateifu

    try:
        cube = Cube(plateifu = ifu)
        print(ifu, cube.nsa['z'])
        test.append(cube.nsa['z'])

    except:
        print(f"No cube for {ifu}")

xaxis = np.arange(0, len(test), 1)
plt.scatter(xaxis, test)
# Out:
# 8481-6103 0.04674866
# [WARNING]: cannot load NSA information for mangaid='51-77'. (MarvinUserWarning)
# No cube for 12040-6102
# 9028-3702 0.04822156
# [WARNING]: cannot load NSA information for mangaid='51-70'. (MarvinUserWarning)
# No cube for 10148-1901
# 8249-3703 0.026438024
# 8137-12705 0.0409416
# 8991-1901 0.05013228
# 8322-6104 0.046931956
# 8091-9101 0.031411078
# 8247-9101 0.041565735

# %%
# the above method is slow and inefficient and sometimes fails completely when it finds a galaxy that lacks NSA params
# Query is much faster:

from marvin.tools.query import Query

my_filter = 'nsa.z < 0.05'
q = Query(search_filter=my_filter)
print(q)

# run the query
r = q.run()

# print some results information
print(r)
print('number of results:', r.totalcount)
# Out:
# Marvin Query(filter='nsa.z < 0.05', mode='remote', data_origin='api')
# Marvin Results(query=nsa.z < 0.05, totalcount=7151, count=100, mode=remote)
# number of results: 7151

# %% [markdown]
# Easy First Step: Rotation Curve
# Steps:
# 1. Import units and constants
# 2. Seach for galaxies, start with a filter where the inclination angle ~ 0 degrees to our viewing plane
# 3. Get a stellar velocity dispersion map for every such galaxy
# 4. Calculate mass from the velocities
#
# * using previous work (STARS final project) as hints

# %% [markdown]
# elpetro_ba is the b/a ratio. a high b/a (close to 1) means that the galaxy is close to perfectly face-on, while a low b/a (close to 0) means that the galaxy is perfectly edge-on

# %%
my_filter = 'nsa.elpetro_ba > 0.25 and nsa.elpetro_ba < 0.5'
q = Query(search_filter=my_filter)
print(q)

# run the query
r = q.run()

# print some results information
print('number of results:', r.totalcount)
# Out:
# Marvin Query(filter='nsa.elpetro_ba > 0.25 and nsa.elpetro_ba < 0.5', mode='remote', data_origin='api')
# number of results: 1597

# %%
myfilter = 'nsa.sersic_logmass > 10 and nsa.sersic_logmass < 12 and nsa.elpetro_ba > 0.2 and nsa.elpetro_ba < 0.5'
q = Query(search_filter = myfilter) 
results = q.run()
    
# Get the total count of results
total_count = results.totalcount
print(total_count)
# Out:
# 601

# %%
#query_params.list_params()
query = Query(search_filter = myfilter, limit = total_count)
results = query.run()

mangaids = []
sersic_logmass = []

for i in range(total_count):
    #print(i, results.results[i])
    mangaids.append(results.results[i][0])
    sersic_logmass.append(results.results[i][2])

print(mangaids[0:100])
# Out:
# ['1-10177', '1-10425', '1-106664', '1-107841', '1-108250', '1-109244', '1-109394', '1-109909', '1-113418', '1-114325', '1-114973', '1-115128', '1-115162', '1-115317', '1-115345', '1-115365', '1-115380', '1-115427', '1-115435', '1-116087', '1-117014', '1-117088', '1-117635', '1-117981', '1-118221', '1-118970', '1-119740', '1-120803', '1-120955', '1-121236', '1-122094', '1-122535', '1-124604', '1-131242', '1-131338', '1-133926', '1-134597', '1-134614', '1-134848', '1-135072', '1-135139', '1-135255', '1-135371', '1-135383', '1-135440', '1-135516', '1-135545', '1-135641', '1-135668', '1-135810', '1-135911', '1-136027', '1-136034', '1-136125', '1-136307', '1-138276', '1-146440', '1-147521', '1-148615', '1-148691', '1-148987', '1-149384', '1-149454', '1-149512', '1-149556', '1-149610', '1-149650', '1-149678', '1-149896', '1-150906', '1-150962', '1-151637', '1-152053', '1-152263', '1-152806', '1-153028', '1-153142', '1-153332', '1-156137', '1-163668', '1-163963', '1-164265', '1-164370', '1-167083', '1-167380', '1-167564', '1-167627', '1-172986', '1-173385', '1-173605', '1-174390', '1-174475', '1-174895', '1-174952', '1-175928', '1-176142', '1-176983', '1-177034', '1-177221', '1-177434']

# %%
#test = np.arange(1, len(sersic_logmass)+1, 1)

nbins = 100

avg_logmass = (np.sum(sersic_logmass) / len(sersic_logmass))

fig, ax = plt.subplots(1, 2)
ax[0].hist(sersic_logmass, bins = nbins)
ax[1].hist(sersic_logmass, bins = nbins)
ax[0].set_xlabel("Log Base 10 of Mass")
ax[0].set_ylabel("# of Galaxies")
ax[1].set_xlabel("Log Base 10 of Mass")
ax[1].set_ylabel("Log Base 10 of # of Galaxies")
ax[1].set_yscale("log")
#plt.axvline(x=avg_logmass, color='tab:red', linestyle='--', label= f'Average Sersic Log Mass = {avg_logmass:.2f}')
plt.suptitle("Stellar Mass Functions for Galaxies in Marvin SDSS DR17")
ax[0].set_title(f"Number of galaxies in the survey: {len(sersic_logmass)}", fontsize = 8)
ax[1].set_title(f"Number of galaxies in the survey: {len(sersic_logmass)}", fontsize = 8)
#ax.legend()
plt.show()

# %%
#testifus = ['8485-1901', '8987-12702']
stellarvel = []
stellarsigmacorr = []
radius = []

for index, mid in enumerate(mangaids[0:10]):
    print(index, mid)
    tries = 0
    while tries < 3:
        
        try:
            maps = Maps(mangaid = mid)
            stellar_velocity = maps.getMap('stellar_vel')            # Stellar velocity is stored in the 'stellar_vel' property.
            stellarvel.append(stellar_velocity)
            stellar_sigma_raw = maps.getMap('stellar_sigma')         # The raw stellar velocity dispersion is in 'stellar_sigma'; must be corrected for instrumental resolution.
            stellar_sigma_corrected = stellar_sigma_raw.inst_sigma_correction()  # Apply the instrumental correction to the velocity dispersion. This will ignore points where the correction is larger than the raw value.
            stellarsigmacorr.append(stellar_sigma_corrected)
            radiusmap = maps.getMap('spx_ellcoo_r_re')
            radius.append(radiusmap)
            break

        except marvin.core.exceptions.MarvinError:
            print("marvin.core.exceptions.MarvinError")
            time.sleep(15)
            tries += 1

        if tries == 3:
            print("Uh oh!")
# Out:
# 0 1-10177
# [WARNING]: divide by zero encountered in divide (RuntimeWarning)
# [WARNING]: invalid value encountered in multiply (RuntimeWarning)
# [WARNING]: invalid value encountered in divide (RuntimeWarning)
# 1 1-10425
# 2 1-106664
# 3 1-107841
# 4 1-108250
# [WARNING]: invalid value encountered in sqrt (RuntimeWarning)
# 5 1-109244
# 6 1-109394
# 7 1-109909
# 8 1-113418
# 9 1-114325

# %%
fname = 'C:/Users/steph/sas/dr17/manga/spectro/analysis/v3_1_1/3.1.0/dapall-v3_1_1-3.1.0.fits'
dapall = fits.getdata(fname)

results = {}

filepath = "C:/Users/steph/DMratios.csv"
if os.path.exists(filepath):
    with open(filepath, 'r') as f_in:

        try:
            lines = f_in.readlines()
            for line in lines:
                mid, rot_Mass, lum_Mass, Mratio = line.split(',')
                results[mid] = (rot_Mass, lum_Mass, Mratio)
        except:
            pass

print(results.keys())

DMratios = []   # probably delete this later because the file itself has the mass ratio information

with open(filepath, 'a') as f_out: 
    
    for index, mid in enumerate(mangaids):
        print(index, mid, end = " ")
        
        if mid not in results.keys():
            row = dapall[dapall['MANGAID'] == mid]
            ba = row['NSA_ELPETRO_BA'][0]
            phi = row['NSA_ELPETRO_PHI'][0]
            theta=-(90-phi)
            a = 15     # why 15?
            b = ba*a   # this depends on choice of a
    
            tries = 0
            while tries < 3:
            
                try:
                    # 2 API calls in this block
                    maps = Maps(mangaid = mid, mode = 'remote')
                    cube = Cube(mid)
                    testvmap = maps['stellar_sigma']
                    testrmap = (maps['spx_ellcoo_r_re'].value * dapall[dapall['MANGAID'] == mid]['nsa_elpetro_th50_r'])
                    break
    
                except Exception as e:
                    print(e)
                    time.sleep(5)
                    tries += 1
    
            if tries == 3:
                print("Out of tries!")
    
            # 0 API calls in this block
            c = testvmap.shape[0]//2
            aperture = cube.getAperture((c,c),(a,b,np.radians(theta)),aperture_type='elliptical')
            spax = aperture.getSpaxels()
    
            # 0 API calls
            mmap = np.zeros(testvmap.shape)
            for spaxel in spax:
                x = spaxel.x
                y = spaxel.y
                v = testvmap[y,x]   # spaxels returned as (y,x) ordered pairs
                r = testrmap[y,x]
        
                m = ((v.value**2)*((r*u.kpc).to(u.km).value)/(C.G.to(u.km**3 / u.M_sun / u.s**2).value))
                #print(v, r, m)
                mmap[y,x] = m
    
            # 0 API calls
            rot_Mass = mmap.max()
            lum_Mass = 10 ** Maps(mid).nsa['sersic_logmass']
            Mratio = rot_Mass / lum_Mass
            print(rot_Mass, lum_Mass, Mratio)
            DMratios.append(Mratio)
            results[mid] = (rot_Mass, lum_Mass, Mratio)
            
            f_out.write(f"{mid},{rot_Mass},{lum_Mass},{Mratio}\n")
    
        else:
            print("Galaxy already processed")

# total API calls = 2 per loop


#plt.imshow(mmap,origin='lower', cmap = 'viridis')
#plt.colorbar(label='Mass (in Solar Masses)', orientation = 'vertical')
#plt.title('Cumulative Mass Map')
#plt.xlabel('Spaxels')
#plt.ylabel('Spaxels')
# Out:
# dict_keys(['1-10177', '1-10425', '1-106664', '1-107841', '1-108250', '1-109244', '1-109394', '1-109909', '1-113418', '1-114325', '1-114973', '1-115128', '1-115162', '1-115317', '1-115345', '1-115365', '1-115380', '1-115427', '1-115435', '1-116087', '1-117014', '1-117088', '1-117635', '1-117981', '1-118221', '1-118970', '1-119740', '1-120803', '1-120955', '1-121236', '1-122094', '1-122535', '1-124604', '1-131242', '1-131338', '1-133926', '1-134597', '1-134614', '1-134848', '1-135072', '1-135139', '1-135255', '1-135371', '1-135383', '1-135440', '1-135516', '1-135545', '1-135641', '1-135668', '1-135810', '1-135911', '1-136027', '1-136034', '1-136125', '1-136307', '1-138276', '1-146440', '1-147521', '1-148615', '1-148691', '1-148987', '1-149384', '1-149454', '1-149512', '1-149556', '1-149610', '1-149650', '1-149678', '1-149896', '1-150906', '1-150962', '1-151637', '1-152053', '1-152263', '1-152806', '1-153028', '1-153142', '1-153332', '1-156137', '1-163668', '1-163963', '1-164265', '1-164370', '1-167083', '1-167380', '1-167564', '1-167627', '1-172986', '1-173385', '1-173605', '1-174390', '1-174475', '1-174895', '1-174952', '1-175928', '1-176142', '1-176983', '1-177034', '1-177221', '1-177434', '1-177959', '1-178065', '1-178542', '1-178686', '1-178908', '1-178938', '1-179083', '1-179246', '1-179321', '1-179479', '1-179556', '1-179781', '1-180168', '1-180298', '1-180513', '1-182818', '1-1832', '1-186329', '1-188803', '1-195337', '1-195478', '1-196597', '1-196630', '1-198747', '1-201173', '1-201816', '1-201874', '1-202760', '1-208943', '1-210355', '1-210388', '1-210711', '1-210731', '1-210736', '1-210752', '1-210802', '1-210822', '1-211082', '1-211257', '1-211491', '1-211515', '1-211525', '1-211790', ' 1-2125', '1-212586', '12-129612', '1-213414', '1-214751', '1-216973', '1-217649', '1-217828', '1-217978', '1-218293', '1-218728', '1-229470', '1-229615', '1-22970', '1-229705', '1-23015', '1-230850', '1-230972', '1-231135', '1-231358', '1-23179', '1-233399', '1-233546', '1-233594', '1-233925', '1-234176', '1-234270', '1-234618', '1-235986', '1-23784', '1-23877', '1-24148', '1-24172', '1-24179', '1-244590', '1-244629', '1-245695', '1-24652', '1-246570', '1-246656', '1-246760', '1-247223', '1-247320', '1-247377', '1-247417', '1-247614', '1-247661', '1-24798', '1-24814', '1-248208', '1-248289', '1-248638', '1-248848', '1-248992', '1-250479', '1-250603', '1-250806', '1-251043', '1-251307', '1-252202', '1-254146', '1-255916', '1-255938', '1-25609', '1-256104', '1-25656', '1-256574', '1-25771', '1-258555', '1-258631', '1-258988', '1-259108', '1-260481', '1-26135', '1-26172', '1-263747', '1-264059', '1-264427', '1-264510', '1-265338', '1-26536', '1-265474', '1-265639', '1-265769', '1-265783', '1-266112', '1-268956', '1-269177', '1-269279', '1-26934', '1-269491', '1-269986', '1-270107', '1-270240', '1-270440', '1-270684', '1-270712', '1-271724', '1-272080', '1-272178', '1-272473', '1-273427', '1-274323', '1-275456', '1-277552', '1-278153', '1-278191', '1-278490', '1-27925', '1-28052', '1-282144', '1-282600', '1-282762', '1-283152', '1-284329', '12-84627', '1-285021', '1-285031', '1-286909', '1-294356', '1-294633', '1-294992', '1-296', '1-296149', '1-296466', '1-296690', '1-296732', '1-297854', '1-298089', '1-298298', '1-298798', '1-298842', '1-299476', '1-299973', '1-300461', '1-300625', '1-300968', '1-30632', '1-313322', '1-314386', '1-314424', '1-316920', '1-317727', '1-317938', '1-318089', '1-318146', '1-318315', '1-318397', '1-319646', '1-319961', '1-320912', '1-321057', '1-321739', '1-322586', '1-322806', '1-323860', '1-324389', '1-324635', '1-324658', '1-325869', '1-325995', '1-326001', '1-33227', '1-333998', '1-335786', '1-336336', '1-336486', '1-336777', '1-338771', '1-338963', '1-339042', '1-339125', '1-34048', '1-351751', '1-351890', '1-35296', '1-35362', '1-35523', '1-35671', '1-35716', '1-36357', '1-36698', '1-36832', '1-368603', '1-36925', '1-36927', '1-36945', '1-37388', '1-37418', '1-374963', '1-37547', '1-375679', '1-376330', ' ...
# 0 1-10177 Galaxy already processed
# 1 1-10425 Galaxy already processed
# 2 1-106664 Galaxy already processed
# 3 1-107841 Galaxy already processed
# 4 1-108250 Galaxy already processed
# 5 1-109244 Galaxy already processed
# 6 1-109394 Galaxy already processed
# 7 1-109909 Galaxy already processed
# 8 1-113418 Galaxy already processed
# 9 1-114325 Galaxy already processed
# 10 1-114973 Galaxy already processed
# 11 1-115128 Galaxy already processed
# 12 1-115162 Galaxy already processed
# 13 1-115317 Galaxy already processed
# 14 1-115345 Galaxy already processed
# 15 1-115365 Galaxy already processed
# 16 1-115380 Galaxy already processed
# 17 1-115427 Galaxy already processed
# 18 1-115435 Galaxy already processed
# 19 1-116087 Galaxy already processed
# 20 1-117014 Galaxy already processed
# 21 1-117088 Galaxy already processed
# 22 1-117635 Galaxy already processed
# 23 1-117981 Galaxy already processed
# 24 1-118221 Galaxy already processed
# 25 1-118970 Galaxy already processed
# 26 1-119740 Galaxy already processed
# 27 1-120803 Galaxy already processed
# 28 1-120955 Galaxy already processed
# 29 1-121236 Galaxy already processed
# 30 1-122094 Galaxy already processed
# 31 1-122535 Galaxy already processed
# 32 1-124604 Galaxy already processed
# 33 1-131242 Galaxy already processed
# 34 1-131338 Galaxy already processed
# 35 1-133926 Galaxy already processed
# 36 1-134597 Galaxy already processed
# 37 1-134614 Galaxy already processed
# 38 1-134848 Galaxy already processed
# 39 1-135072 Galaxy already processed
# 40 1-135139 Galaxy already processed
# 41 1-135255 Galaxy already processed
# 42 1-135371 Galaxy already processed
# 43 1-135383 Galaxy already processed
# 44 1-135440 Galaxy already processed
# 45 1-135516 Galaxy already processed
# 46 1-135545 Galaxy already processed
# 47 1-135641 Galaxy already processed
# 48 1-135668 Galaxy already processed
# 49 1-135810 Galaxy already processed
# 50 1-135911 Galaxy already processed
# 51 1-136027 Galaxy already processed
# 52 1-136034 Galaxy already processed
# 53 1-136125 Galaxy already processed
# 54 1-136307 Galaxy already processed
# 55 1-138276 Galaxy already processed
# 56 1-146440 Galaxy already processed
# 57 1-147521 Galaxy already processed
# 58 1-148615 Galaxy already processed
# 59 1-148691 Galaxy already processed
# 60 1-148987 Galaxy already processed
# 61 1-149384 Galaxy already processed
# 62 1-149454 Galaxy already processed
# 63 1-149512 Galaxy already processed
# 64 1-149556 Galaxy already processed
# 65 1-149610 Galaxy already processed
# 66 1-149650 Galaxy already processed
# 67 1-149678 Galaxy already processed
# 68 1-149896 Galaxy already processed
# 69 1-150906 Galaxy already processed
# 70 1-150962 Galaxy already processed
# 71 1-151637 Galaxy already processed
# 72 1-152053 Galaxy already processed
# 73 1-152263 Galaxy already processed
# 74 1-152806 Galaxy already processed
# 75 1-153028 Galaxy already processed
# 76 1-153142 Galaxy already processed
# 77 1-153332 Galaxy already processed
# 78 1-156137 Galaxy already processed
# 79 1-163668 Galaxy already processed
# 80 1-163963 Galaxy already processed
# 81 1-164265 Galaxy already processed
# 82 1-164370 Galaxy already processed
# 83 1-167083 Galaxy already processed
# 84 1-167380 Galaxy already processed
# 85 1-167564 Galaxy already processed
# 86 1-167627 Galaxy already processed
# 87 1-172986 Galaxy already processed
# 88 1-173385 Galaxy already processed
# 89 1-173605 Galaxy already processed
# 90 1-174390 Galaxy already processed
# 91 1-174475 Galaxy already processed
# 92 1-174895 Galaxy already processed
# 93 1-174952 Galaxy already processed
# 94 1-175928 Galaxy already processed
# 95 1-176142 Galaxy already processed
# 96 1-176983 Galaxy already processed
# 97 1-177034 Galaxy already processed
# 98 1-177221 Galaxy already processed
# 99 1-177434 Galaxy already processed
# 100 1-177959 Galaxy already processed
# 101 1-178065 Galaxy already processed
# 102 1-178542 Galaxy already processed
# 103 1-178686 Galaxy already processed
# 104 1-178908 Galaxy already processed
# 105 1-178908 Galaxy already processed
# 106 1-178938 Galaxy already processed
# 107 1-178938 Galaxy already processed
# 108 1-179083 Galaxy already processed
# 109 1-179246 Galaxy already processed
# 110 1-179246 Galaxy already processed
# 111 1-179321 Galaxy already processed
# 112 1-179479 Galaxy already processed
# 113 1-179556 Galaxy already processed
# 114 1-179781 Galaxy already processed
# 115 1-180168 Galaxy already processed
# 116 1-180298 Galaxy already processed
# 117 1-180513 Galaxy already processed
# 118 1-182818 Galaxy already processed
# 119 1-1832 Galaxy already processed
# 120 1-186329 Galaxy already processed
# 121 1-188803 Galaxy already processed
# 122 1-195337 Galaxy already processed
# 123 1-195478 Galaxy already processed
# 124 1-196597 Galaxy already processed
# 125 1-196630 Galaxy already processed
# 126 1-198747 Galaxy already processed
# 127 1-201173 Galaxy already processed
# 128 1-201816 Galaxy already processed
# 129 1-201874 Galaxy already processed
# 130 1-202760 Galaxy already processed
# 131 1-208943 Galaxy already processed
# 132 1-210355 Galaxy already processed
# 133 1-210388 Galaxy already processed
# 134 1-210711 Galaxy already processed
# 135 1-210731 Galaxy already processed
# 136 1-210736 Galaxy already processed
# 137 1-210752 Galaxy already processed
# 138 1-210802 Galaxy already processed
# 139 1-210822 Galaxy already processed
# 140 1-211082 Galaxy already processed
# 141 1-211257 Galaxy already processed
# 142 1-211491 Galaxy already processed
# 143 1-211515 Galaxy already processed
# 144 1-211525 Galaxy already processed
# 145 1-211790 Galaxy already processed
# 146 1-2125 41241996222.149124 19706148999.999966 2.092849101168838
# 147 1-212586 Galaxy already processed
# 148 12-129612 Galaxy already processed
# 149 1-213414 Galaxy already processed
# 150 1-214751 Galaxy already processed
# 151 1-216973 Galaxy already processed
# 152 1-217649 Galaxy already processed
# 153 1-217828 Galaxy already processed
# 154 1-217978 Galaxy already processed
# 155 1-218293 Galaxy already processed
# 156 1-218728 Galaxy already processed
# 157 1-229470 Galaxy already processed
# 158 1-229615 Galaxy already processed
# 159 1-22970 Galaxy already processed
# 160 1-229705 Galaxy already processed
# 161 1-23015 Galaxy already processed
# 162 1-230850 Galaxy already processed
# 163 1-230972 Galaxy already processed
# 164 1-231135 Galaxy already processed
# 165 1-231358 Galaxy already processed
# 166 1-23179 Galaxy already processed
# 167 1-233399 Galaxy already processed
# 168 1-233546 Galaxy already processed
# 169 1-233594 Galaxy already processed
# 170 1-233925 Galaxy already processed
# 171 1-234176 Galaxy already processed
# 172 1-234270 Galaxy already processed
# 173 1-234618 Galaxy already processed
# 174 1-235986 Galaxy already processed
# 175 1-23784 Galaxy already processed
# 176 1-23877 Galaxy already processed
# 177 1-24148 Galaxy already processed
# 178 1-24172 Galaxy already processed
# 179 1-24179 Galaxy already processed
# 180 1-244590 Galaxy already processed
# 181 1-244629 Galaxy already processed
# 182 1-245695 Galaxy already processed
# 183 1-24652 Galaxy already processed
# 184 1-246570 Galaxy already processed
# 185 1-246656 Galaxy already processed
# 186 1-246760 Galaxy already processed
# 187 1-247223 Galaxy already processed
# 188 1-247320 Galaxy already processed
# 189 1-247377 Galaxy already processed
# 190 1-247417 Galaxy already processed
# 191 1-247614 Galaxy already processed
# 192 1-247661 Galaxy already processed
# 193 1-24798 Galaxy already processed
# 194 1-24814 Galaxy already processed
# 195 1-248208 Galaxy already processed
# 196 1-248289 Galaxy already processed
# 197 1-248638 Galaxy already processed
# 198 1-248848 Galaxy already processed
# 199 1-248992 Galaxy already processed
# 200 1-250479 Galaxy already processed
# 201 1-250603 Galaxy already processed
# 202 1-250806 Galaxy already processed
# 203 1-251043 Galaxy already processed
# 204 1-251307 Galaxy already processed
# 205 1-252202 Galaxy already processed
# 206 1-254146 Galaxy already processed
# 207 1-255916 Galaxy already processed
# 208 1-255938 Galaxy already processed
# 209 1-25609 Galaxy already processed
# 210 1-256104 Galaxy already processed
# 211 1-256104 Galaxy already processed
# 212 1-256104 Galaxy already processed
# 213 1-25656 Galaxy already processed
# 214 1-256574 Galaxy already processed
# 215 1-25771 Galaxy already processed
# 216 1-258555 Galaxy already processed
# 217 1-258631 Galaxy already processed
# 218 1-258988 Galaxy already processed
# 219 1-259108 Galaxy already processed
# 220 1-260481 Galaxy already processed
# 221 1-26135 Galaxy already processed
# 222 1-26172 Galaxy already processed
# 223 1-263747 Galaxy already processed
# 224 1-264059 Galaxy already processed
# 225 1-264427 Galaxy already processed
# 226 1-264510 Galaxy already processed
# 227 1-265338 Galaxy already processed
# 228 1-26536 Galaxy already processed
# 229 1-265474 Galaxy already processed
# 230 1-265639 Galaxy already processed
# 231 1-265769 Galaxy already processed
# 232 1-265783 Galaxy already processed
# 233 1-266112 Galaxy already processed
# 234 1-268956 Galaxy already processed
# 235 1-269177 Galaxy already processed
# 236 1-269279 Galaxy already processed
# 237 1-26934 Galaxy already processed
# 238 1-269491 Galaxy already processed
# 239 1-269986 Galaxy already processed
# 240 1-270107 Galaxy already processed
# 241 1-270240 Galaxy already processed
# 242 1-270440 Galaxy already processed
# 243 1-270684 Galaxy already processed
# 244 1-270712 Galaxy already processed
# 245 1-271724 Galaxy already processed
# 246 1-272080 Galaxy already processed
# 247 1-272178 Galaxy already processed
# 248 1-272473 Galaxy already processed
# 249 1-273427 Galaxy already processed
# 250 1-274323 Galaxy already processed
# 251 1-275456 Galaxy already processed
# 252 1-277552 Galaxy already processed
# 253 1-278153 Galaxy already processed
# 254 1-278191 Galaxy already processed
# 255 1-278490 Galaxy already processed
# 256 1-27925 Galaxy already processed
# 257 1-28052 Galaxy already processed
# 258 1-282144 Galaxy already processed
# 259 1-282600 Galaxy already processed
# 260 1-282762 Galaxy already processed
# 261 1-283152 Galaxy already processed
# 262 1-284329 Galaxy already processed
# 263 12-84627 Galaxy already processed
# 264 1-285021 Galaxy already processed
# 265 1-285031 Galaxy already processed
# 266 1-286909 Galaxy already processed
# 267 1-294356 Galaxy already processed
# 268 1-294633 Galaxy already processed
# 269 1-294992 Galaxy already processed
# 270 1-296 Galaxy already processed
# 271 1-296149 Galaxy already processed
# 272 1-296466 Galaxy already processed
# 273 1-296690 Galaxy already processed
# 274 1-296732 Galaxy already processed
# 275 1-297854 Galaxy already processed
# 276 1-298089 Galaxy already processed
# 277 1-298298 Galaxy already processed
# 278 1-298798 Galaxy already processed
# 279 1-298842 Galaxy already processed
# 280 1-299476 Galaxy already processed
# 281 1-299973 Galaxy already processed
# 282 1-300461 Galaxy already processed
# 283 1-300625 Galaxy already processed
# 284 1-300968 Galaxy already processed
# 285 1-30632 Galaxy already processed
# 286 1-313322 Galaxy already processed
# 287 1-314386 Galaxy already processed
# 288 1-314424 Galaxy already processed
# 289 1-316920 Galaxy already processed
# 290 1-317727 Galaxy already processed
# 291 1-317938 Galaxy already processed
# 292 1-318089 Galaxy already processed
# 293 1-318146 Galaxy already processed
# 294 1-318315 Galaxy already processed
# 295 1-318397 Galaxy already processed
# 296 1-319646 Galaxy already processed
# 297 1-319961 Galaxy already processed
# 298 1-320912 Galaxy already processed
# 299 1-321057 Galaxy already processed
# 300 1-321739 Galaxy already processed
# 301 1-322586 Galaxy already processed
# 302 1-322806 Galaxy already processed
# 303 1-323860 Galaxy already processed
# 304 1-324389 Galaxy already processed
# 305 1-324635 Galaxy already processed
# 306 1-324658 Galaxy already processed
# 307 1-325869 Galaxy already processed
# 308 1-325995 Galaxy already processed
# 309 1-326001 Galaxy already processed
# 310 1-33227 Galaxy already processed
# 311 1-333998 Galaxy already processed
# 312 1-335786 Galaxy already processed
# 313 1-336336 Galaxy already processed
# 314 1-336486 Galaxy already processed
# 315 1-336777 Galaxy already processed
# 316 1-338771 Galaxy already processed
# 317 1-338963 Galaxy already processed
# 318 1-339042 Galaxy already processed
# 319 1-339125 Galaxy already processed
# 320 1-34048 Galaxy already processed
# 321 1-351751 Galaxy already processed
# 322 1-351890 Galaxy already processed
# 323 1-35296 Galaxy already processed
# 324 1-35362 Galaxy already processed
# 325 1-35523 Galaxy already processed
# 326 1-35671 Galaxy already processed
# 327 1-35716 Galaxy already processed
# 328 1-36357 Galaxy already processed
# 329 1-36698 Galaxy already processed
# 330 1-36832 Galaxy already processed
# 331 1-368603 Galaxy already processed
# 332 1-36925 Galaxy already processed
# 333 1-36927 Galaxy already processed
# 334 1-36945 Galaxy already processed
# 335 1-37388 Galaxy already processed
# 336 1-37418 Galaxy already processed
# 337 1-374963 Galaxy already processed
# 338 1-37547 Galaxy already processed
# 339 1-375679 Galaxy already processed
# 340 1-376330 Galaxy already processed
# 341 1-376334 Galaxy already processed
# 342 1-376419 Galaxy already processed
# 343 1-37818 Galaxy already processed
# 344 1-378479 Galaxy already processed
# 345 1-379454 Galaxy already processed
# 346 1-379741 Galaxy already processed
# 347 1-37980 Galaxy already processed
# 348 1-38007 Galaxy already processed
# 349 1-380299 Galaxy already processed
# 350 1-38075 Galaxy already processed
# 351 1-38101 Galaxy already processed
# 352 1-38160 Galaxy already processed
# 353 1-38168 Galaxy already processed
# 354 1-382273 Galaxy already processed
# 355 1-382557 Galaxy already processed
# 356 1-382678 Galaxy already processed
# 357 1-382817 Galaxy already processed
# 358 1-382889 Galaxy already processed
# 359 1-38354 Galaxy already processed
# 360 1-38381 Galaxy already processed
# 361 1-384396 Galaxy already processed
# 362 1-385225 Galaxy already processed
# 363 1-386120 Galaxy already processed
# 364 1-386695 Galaxy already processed
# 365 1-386903 Galaxy already processed
# 366 1-387106 Galaxy already processed
# 367 1-389513 Galaxy already processed
# 368 1-390054 Galaxy already processed
# 369 1-390282 Galaxy already processed
# 370 1-390514 Galaxy already processed
# 371 1-39063 Galaxy already processed
# 372 1-395508 Galaxy already processed
# 373 1-395780 Galaxy already processed
# 374 1-397212 Galaxy already processed
# 375 1-397451 Galaxy already processed
# 376 1-39759 Galaxy already processed
# 377 1-39909 Galaxy already processed
# 378 1-399563 Galaxy already processed
# 379 1-40058 Galaxy already processed
# 380 1-401708 Galaxy already processed
# 381 1-401919 Galaxy already processed
# 382 1-403982 Galaxy already processed
# 383 1-404032 Galaxy already processed
# 384 1-404070 Galaxy already processed
# 385 1-404102 Galaxy already processed
# 386 1-40577 Galaxy already processed
# 387 1-40755 Galaxy already processed
# 388 1-40826 Galaxy already processed
# 389 1-409240 Galaxy already processed
# 390 1-409242 Galaxy already processed
# 391 1-409576 Galaxy already processed
# 392 1-411980 Galaxy already processed
# 393 1-412043 Galaxy already processed
# 394 1-412128 Galaxy already processed
# 395 1-412631 Galaxy already processed
# 396 1-415475 Galaxy already processed
# 397 1-415848 Galaxy already processed
# 398 1-415939 Galaxy already processed
# 399 1-41597 Galaxy already processed
# 400 1-418111 Galaxy already processed
# 401 1-418252 Galaxy already processed
# 402 1-419301 Galaxy already processed
# 403 1-42007 Galaxy already processed
# 404 1-420973 Galaxy already processed
# 405 1-421767 Galaxy already processed
# 406 1-421972 Galaxy already processed
# 407 1-422947 Galaxy already processed
# 408 1-424415 Galaxy already processed
# 409 1-42548 Galaxy already processed
# 410 1-43864 Galaxy already processed
# 411 1-44013 Galaxy already processed
# 412 1-44117 Galaxy already processed
# 413 1-44180 Galaxy already processed
# 414 1-44361 Galaxy already processed
# 415 1-44379 Galaxy already processed
# 416 1-445626 Galaxy already processed
# 417 1-445669 Galaxy already processed
# 418 1-44693 Galaxy already processed
# 419 1-44763 Galaxy already processed
# 420 1-44801 Galaxy already processed
# 421 1-45208 Galaxy already processed
# 422 1-455630 Galaxy already processed
# 423 1-456001 Galaxy already processed
# 424 1-456404 Galaxy already processed
# 425 1-456488 Galaxy already processed
# 426 1-456759 Galaxy already processed
# 427 1-456915 Galaxy already processed
# 428 1-456937 Galaxy already processed
# 429 1-456996 Galaxy already processed
# 430 1-458127 Galaxy already processed
# 431 1-459619 Galaxy already processed
# 432 1-460862 Galaxy already processed
# 433 1-46266 Galaxy already processed
# 434 1-464061 Galaxy already processed
# 435 1-464063 Galaxy already processed
# 436 1-464461 Galaxy already processed
# 437 1-46562 Galaxy already processed
# 438 1-474825 Galaxy already processed
# 439 1-481814 Galaxy already processed
# 440 1-50472 Galaxy already processed
# 441 1-50542 Galaxy already processed
# 442 1-50982 Galaxy already processed
# 443 1-51327 Galaxy already processed
# 444 1-51369 Galaxy already processed
# 445 1-51660 Galaxy already processed
# 446 1-51886 Galaxy already processed
# 447 1-523065 Galaxy already processed
# 448 1-523105 Galaxy already processed
# 449 1-53328 Galaxy already processed
# 450 1-53660 Galaxy already processed
# 451 1-53660 Galaxy already processed
# 452 1-53870 Galaxy already processed
# 453 1-53870 Galaxy already processed
# 454 1-54080 Galaxy already processed
# 455 1-543357 Galaxy already processed
# 456 1-543416 Galaxy already processed
# 457 1-545967 Galaxy already processed
# 458 1-547738 Galaxy already processed
# 459 1-548004 Galaxy already processed
# 460 1-54809 Galaxy already processed
# 461 1-548626 Galaxy already processed
# 462 1-55065 Galaxy already processed
# 463 1-55648 Galaxy already processed
# 464 1-556549 Galaxy already processed
# 465 1-558247 Galaxy already processed
# 466 1-558248 Galaxy already processed
# 467 1-558926 Galaxy already processed
# 468 1-559153 Galaxy already processed
# 469 1-560832 Galaxy already processed
# 470 1-561017 Galaxy already processed
# 471 1-561017 Galaxy already processed
# 472 1-564429 Galaxy already processed
# 473 1-564482 Galaxy already processed
# 474 1-564591 Galaxy already processed
# 475 1-567443 Galaxy already processed
# 476 1-569034 Galaxy already processed
# 477 1-569077 Galaxy already processed
# 478 1-569095 Galaxy already processed
# 479 1-569313 Galaxy already processed
# 480 1-570609 Galaxy already processed
# 481 1-575151 Galaxy already processed
# 482 1-575186 Galaxy already processed
# 483 1-575741 Galaxy already processed
# 484 1-575847 Galaxy already processed
# 485 1-576537 Galaxy already processed
# 486 1-576544 Galaxy already processed
# 487 1-576558 Galaxy already processed
# 488 1-579533 Galaxy already processed
# 489 1-582042 Galaxy already processed
# 490 1-585171 Galaxy already processed
# 491 1-585188 Galaxy already processed
# 492 1-585221 Galaxy already processed
# 493 1-585230 Galaxy already processed
# 494 1-585282 Galaxy already processed
# 495 1-585474 Galaxy already processed
# 496 1-585711 Galaxy already processed
# 497 1-586415 Galaxy already processed
# 498 1-587259 Galaxy already processed
# 499 1-590252 Galaxy already processed
# 500 1-591055 Galaxy already processed
# 501 1-594097 Galaxy already processed
# 502 1-594116 Galaxy already processed
# 503 1-594358 Galaxy already processed
# 504 1-594582 Galaxy already processed
# 505 1-594602 Galaxy already processed
# 506 1-595093 Galaxy already processed
# 507 1-595204 Galaxy already processed
# 508 1-596957 Galaxy already processed
# 509 1-597528 Galaxy already processed
# 510 1-599614 Galaxy already processed
# 511 1-602993 Galaxy already processed
# 512 1-603212 Galaxy already processed
# 513 1-603215 Galaxy already processed
# 514 1-603624 Galaxy already processed
# 515 1-604039 Galaxy already processed
# 516 1-604231 Galaxy already processed
# 517 1-604856 Galaxy already processed
# 518 1-604873 Galaxy already processed
# 519 1-604937 Galaxy already processed
# 520 1-604985 Galaxy already processed
# 521 1-605013 Galaxy already processed
# 522 1-605195 Galaxy already processed
# 523 1-605270 Galaxy already processed
# 524 1-605282 Galaxy already processed
# 525 1-605753 Galaxy already processed
# 526 1-606005 Galaxy already processed
# 527 1-606022 Galaxy already processed
# 528 1-607106 Galaxy already processed
# 529 1-607739 Galaxy already processed
# 530 1-613769 Galaxy already processed
# 531 1-614456 Galaxy already processed
# 532 1-61513 Galaxy already processed
# 533 1-61630 Galaxy already processed
# 534 1-617503 Galaxy already processed
# 535 1-62063 Galaxy already processed
# 536 1-623389 Galaxy already processed
# 537 1-624367 Galaxy already processed
# 538 1-627411 Galaxy already processed
# 539 1-631871 Galaxy already processed
# 540 1-631993 Galaxy already processed
# 541 1-632610 Galaxy already processed
# 542 1-633191 Galaxy already processed
# 543 1-633414 Galaxy already processed
# 544 1-633683 Galaxy already processed
# 545 1-633805 Galaxy already processed
# 546 1-633994 Galaxy already processed
# 547 1-634089 Galaxy already processed
# 548 1-634144 Galaxy already processed
# 549 1-634149 Galaxy already processed
# 550 1-634183 Galaxy already processed
# 551 1-634588 Galaxy already processed
# 552 1-634763 Galaxy already processed
# 553 1-635285 Galaxy already processed
# 554 1-635476 Galaxy already processed
# 555 1-635478 Galaxy already processed
# 556 1-635503 Galaxy already processed
# 557 1-635503 Galaxy already processed
# 558 1-636015 Galaxy already processed
# 559 1-636870 Galaxy already processed
# 560 1-638093 Galaxy already processed
# 561 1-638109 Galaxy already processed
# 562 1-70384 Galaxy already processed
# 563 1-71 364109842586.5014 37845940000.00003 9.620842885300275
# 564 1-71281 Galaxy already processed
# 565 1-72289 Galaxy already processed
# 566 1-73002 Galaxy already processed
# 567 1-76446 Galaxy already processed
# 568 1-77704 Galaxy already processed
# 569 1-77933 Galaxy already processed
# 570 1-78213 Galaxy already processed
# 571 1-78451 Galaxy already processed
# 572 1-78856 Galaxy already processed
# 573 1-78873 Galaxy already processed
# 574 1-79356 Galaxy already processed
# 575 1-79751 Galaxy already processed
# 576 1-80034 Galaxy already processed
# 577 1-83430 Galaxy already processed
# 578 1-897 Galaxy already processed
# 579 1-90190 Galaxy already processed
# 580 1-90213 Galaxy already processed
# 581 1-91016 Galaxy already processed
# 582 1-91678 Galaxy already processed
# 583 1-93093 Galaxy already processed
# 584 1-93835 Galaxy already processed
# 585 1-94027 Galaxy already processed
# 586 1-94063 Galaxy already processed
# 587 1-94139 Galaxy already processed
# 588 1-94403 Galaxy already processed
# 589 1-94717 Galaxy already processed
# 590 1-94785 Galaxy already processed
# 591 1-95111 Galaxy already processed
# 592 1-95208 Galaxy already processed
# 593 1-95842 Galaxy already processed
# 594 1-96067 Galaxy already processed
# 595 1-96151 21290232035.392193 27905192000.000027 0.762948774385504
# 596 1-96548 28872645003.75697 19754697000.000023 1.461558484230709
# 597 1-98401 43684575934.610664 22068683000.000023 1.9794826875083855
# 598 1-98636 146408364697.0474 185813629999.99982 0.7879312443174784
# 599 1-9923 12350388261.522152 10621213999.999977 1.1628038246402133
# 600 1-999 17998862617.229797 20615462999.99999 0.8730758371630949

# %%
nbins = 100

testedids = []
testedrotmasses = []
testedbarymasses = []
massratios = []

with open(filepath, 'r', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    for row in csv_reader:
        testedids.append(row[0])
        testedrotmasses.append(float(row[1]))
        testedbarymasses.append(float(row[2]))
        massratios.append(float(row[3]))

test = np.arange(1, len(massratios)+1, 1)
avg_DM_ratio = np.sum(massratios) / len(massratios)


fig, ax = plt.subplots()

ax.scatter(test, massratios, color = "tab:blue")
ax.set_xlabel("Galaxy #")
ax.set_ylabel("Dark Matter Fraction (Mrot / Mlum)")
ax.set_ylim(0, 10)
plt.axhline(y = avg_DM_ratio, label = f"Avg DM ratio: {avg_DM_ratio:.2f}", linestyle = "--", color = "tab:red")
plt.suptitle("Dark Matter Content for Galaxies in MaNGA DR17")
ax.set_title(f"Number of galaxies in the survey: {len(massratios)}", fontsize = 10)
ax.legend()
plt.show()
